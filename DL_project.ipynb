# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="snXy6Zb2jDN4F8eRiQe4")
project = rf.workspace("mylab-f5xg9").project("dl_project-tuhm0")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.134`, to intall it `pip install ultralytics==8.0.134`.
#
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to DL_project-1 in yolov8:: 100%|██████████| 362/362 [00:00<00:00, 4378.63it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.7/644.7 kB 7.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolov8s.pt")
model.train(data="/content/DL_project-1/data.yaml", epochs=100,cache=True)
# Out:
# Ultralytics YOLOv8.0.201 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.predict(source="/content/DL_project-1/test/images/005_jpg.rf.73bca0438fd2f6e6afbcb685f2cdf3e1.jpg",save=True,conf=0.5)
# Out:
# image 1/1 /content/DL_project-1/test/images/005_jpg.rf.73bca0438fd2f6e6afbcb685f2cdf3e1.jpg: 320x640 1 0, 226.2ms
# Speed: 9.3ms preprocess, 226.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/detect/train42
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: '0', 1: '1', 2: '2'}
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [228, 228, 228],
#          [230, 230, 230],
#          [230, 230, 230]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [228, 228, 228],
#          [230, 230, 230],
#          [230, 230, 230]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [228, 228, 228],
#          [230, 230, 230],
# ...

# %%
#Sample Prediction
from IPython.display import Image
Image(filename='/content/runs/detect/train42/005_jpg.rf.73bca0438fd2f6e6afbcb685f2cdf3e1.jpg')

# %%
#F1 Curve
Image(filename='/content/runs/detect/train4/F1_curve.png')

# %%
# import os

# # Set the locale to UTF-8
# os.environ['LANG'] = 'en_US.UTF-8'
# os.environ['LC_ALL'] = 'en_US.UTF-8'
# !zip -r file.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/args.yaml (deflated 51%)
#   adding: content/runs/detect/train42/ (stored 0%)
#   adding: content/runs/detect/train42/005_jpg.rf.73bca0438fd2f6e6afbcb685f2cdf3e1.jpg (deflated 34%)
#   adding: content/runs/detect/train2/ (stored 0%)
#   adding: content/runs/detect/train2/weights/ (stored 0%)
#   adding: content/runs/detect/train2/args.yaml (deflated 51%)
#   adding: content/runs/detect/train3/ (stored 0%)
#   adding: content/runs/detect/train3/weights/ (stored 0%)
#   adding: content/runs/detect/train3/args.yaml (deflated 51%)
#   adding: content/runs/detect/train4/ (stored 0%)
#   adding: content/runs/detect/train4/train_batch721.jpg (deflated 21%)
#   adding: content/runs/detect/train4/P_curve.png (deflated 12%)
# ...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
